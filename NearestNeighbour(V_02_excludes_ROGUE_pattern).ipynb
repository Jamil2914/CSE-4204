# %% [markdown]
# <a href="https://colab.research.google.com/github/Jamil2914/CSE-4204/blob/main/NearestNeighbour(V_02_excludes_ROGUE_pattern).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math
import matplotlib.pyplot as plt
from statistics import mean

# %%
try:
    List1 = [[2,4]]
    List2 = [[-4,3]]
    while True:
        print("Input a coordinate : ")
        element = [int(input()),int(input())]
        List3 = []
        List3.append(element)
        res1_list = []
        res2_list = []
        for i in range (len(List1)):
          res1 = math.sqrt(pow((List1[i][0]-List3[0][0]),2)+pow((List1[i][1]-List3[0][1]),2))
          #print((List1[i][0]-List3[0][0]))
          #print(List1[i][1]-List3[0][1])
          #print(res1)
          res1_list.append(res1)
          #print(res1_list)
        for j in range (len(List2)):
          res2 = math.sqrt(pow((List2[j][0]-List3[0][0]),2)+pow((List2[j][1]-List3[0][1]),2))
          res2_list.append(res2)
          #print(res2_list)
        avg1 = mean(res1_list)
        avg2 = mean(res2_list)
        if avg1 < avg2 :
            List1.append(element)
        else :
            List2.append(element)
        x1 = []
        x2 = []
        y1 = []
        y2 = []
        for k in range (len(List1)):
          x1.append(List1[k][0])
        for l in range (len(List2)):
          x2.append(List2[l][0])
        for m in range (len(List1)):
          y1.append(List1[m][1])
        for n in range (len(List2)):
          y2.append(List2[n][1])
        plt.scatter(x1,y1)
        plt.scatter(x2,y2)
        plt.xlabel("X axis")
        plt.ylabel("Y axis")
        plt.show()
        
    
         
except:
    print(List1,"    ",List2)
# Out:
# Input a coordinate :
# -1
# 2
# Input a coordinate :
# 1
# 2
# Input a coordinate :
# -3
# 2
# Input a coordinate :
# 0
# 4
# Input a coordinate :
# 0
# 3
# Input a coordinate :
# -1
# 3
# Input a coordinate :
# -3
# 3
# Input a coordinate :
# Stop
# [[2, 4], [1, 2], [0, 4], [0, 3], [-1, 3]]      [[-4, 3], [-1, 2], [-3, 2], [-3, 3]]
